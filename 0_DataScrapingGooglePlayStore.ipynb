# %%
# %reload_ext watermark
# %watermark -v -p pandas,matplotlib,seaborn,google_play_scraper
# Out:
# Python implementation: CPython
# Python version       : 3.12.3
# IPython version      : 8.23.0
#
# pandas             : 2.2.2
# matplotlib         : 3.9.0
# seaborn            : 0.13.2
# google_play_scraper: 1.2.6

# %%
#!pip install google_play_scraper

# %%
import json
import pandas as pd
from tqdm import tqdm

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

from google_play_scraper import Sort, reviews, app

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

# %% [markdown]
# ## Bank Terbaik 2024
# ### Bank Digital dan Nilai Kapitalisasi Pasarnya (Februari 2023)
# https://databoks.katadata.co.id/teknologi-telekomunikasi/statistik/4b5316c0904a77f/deretan-bank-digital-dan-nilai-kapitalisasi-pasarnya-siapa-paling-besar
#
#
# 1. Bank Jago (ARTO) Rp39,91 triliun
# 2. Allo Bank (BBHI) Rp36,07 triliun
# 3. Bank Aladin Syariah (BANK) Rp19,27 triliun
# 4. Bank Raya (AGRO) Rp10,59 triliun
# 5. Bank Neo Commerce (BBYB) Rp8,07 triliun
#
# ### Terbaik Menurut Kumparan
# https://kumparan.com/berita-bisnis/5-bank-digital-terbaik-di-indonesia-untuk-bertransaksi-23USjxqLAEA/full
#
# 1. Blu BCA
# 2. SeaBank
# 3. Jenius
# 4. Bank Jago
# 5. Neo Bank
#
# ### Terbaik Menurut Katadata Q1 2024
# https://katadata.co.id/finansial/keuangan/6630cd0d0a239/adu-kuat-laba-tiga-bank-digital-di-q1-2024-siapa-jawaranya
# 1. Bank Jago
# 2. Bank Raya
# 3. Allo Bank
#
# ### Terbaik Menurut TOPSIS Unesa (Jurnal)
# https://ejournal.unesa.ac.id/index.php/mathunesa/article/view/53084
#
# 1. Bank Jago (B1) 0,9407
# 2. SeaBank (B4) 0,7998
# 3. Jenius (B3) 0,3741
# 4. Blu (B5) 0,2482
# 5. NeoBank (B2) 0,0051

# %%
app_packages = [
  'com.alloapp.yump', #allo bank
  'com.jago.digitalBanking', #bank jago
  # 'com.senyumkubank.rekeningonline', #amarbank
  # 'id.aladinbank.mobile',
  'id.co.bankbkemobile.digitalbank', #seabank
  'com.btpn.dc', #btpn jenius
  'com.bcadigital.blu', #bank bca
  'id.co.bankraya.apps', #rayabank
  'com.bnc.finance' #neobank
#   'com.supercell.brawlstars',
#   'jp.pokemon.pokemonunite',
]

# %%
app_infos = []

for ap in tqdm(app_packages):
  info = app(ap, lang='id', country='id')
 # del info['comments']
  app_infos.append(info)
# Out:
# 100%|██████████| 7/7 [00:22<00:00,  3.17s/it]

# %%
df=pd.DataFrame(app_infos)

# %%
df.head(10)
# Out:
#                             title  \
# 0                       Allo Bank
# 1  Jago/Jago Syariah bank digital
# 2                         SeaBank
# 3                          Jenius
# 4              blu by BCA Digital
# 5             Raya - Digital Bank
# 6        neobank dari BNC Digital
#
#                                          description  \
# 0  Hi, kini Allo Bank untuk Android hadir!\r\n\r\...
# 1  Jago/Jago Syariah digital bank adalah aplikasi...
# 2  Lebih Untung di SeaBank!\r\nBuka rekening SeaB...
# 3  Cara mudah atur kehidupan/keuangan dengan apli...
# 4  blu Siap Jadi Pegangan Finansialmu!\r\n \r\nbl...
# 5  Bank digital pilihan untuk kelola keuangan per...
# 6  "Saatnya nikmati berbagai kemudahan buat semua...
#
#                                      descriptionHTML  \
# 0  Hi, kini Allo Bank untuk Android hadir!<br><br...
# 1  Jago/Jago Syariah digital bank adalah aplikasi...
# 2  Lebih Untung di SeaBank!<br>Buka rekening SeaB...
# 3  Cara mudah atur kehidupan/keuangan dengan apli...
# 4  blu Siap Jadi Pegangan Finansialmu!<br> <br>bl...
# 5  Bank digital pilihan untuk kelola keuangan per...
# 6  &quot;Saatnya nikmati berbagai kemudahan buat ...
#
#                                              summary     installs  \
# 0  Allo Bank, perbankan digital baru yang akan me...   5.000.000+
# 1  Nabung, transaksi, bayar QRIS & atur uang sema...  10.000.000+
# 2  Aplikasi perbankan digital untuk lakukan aktiv...  10.000.000+
# 3  Cara mudah atur kehidupan/keuangan dengan apli...  10.000.000+
# 4  Mulai Langkahmu Buka Rekening, Menabung, Buka ...   1.000.000+
# 5    Nabung aman, mudah dan menyenangkan #Rayakanlah   1.000.000+
# 6  Layanan digital dari Bank Neo Commerce: tabung...  10.000.000+
#
#    minInstalls  realInstalls     score  ratings  reviews  ...  \
# 0      5000000       8161673  4.119869    42666    26596  ...
# 1     10000000      12004571  4.542278   169334    55927  ...
# 2     10000000      16330685  4.872240  1212285   167517  ...
# 3     10000000      12013059  3.464688   201451   128641  ...
# 4      1000000       3411494  4.625711    93852    26181  ...
# 5      1000000       1157997  4.518599     8796     6803  ...
# 6     10000000      29161663  3.555225   273846   154418  ...
#
#   contentRatingDescription  adSupported  containsAds     released  \
# 0                     None        False        False  14 Mar 2022
# 1                     None        False        False  13 Apr 2021
# 2                     None        False        False  26 Feb 2021
# 3                     None        False        False  10 Agu 2016
# 4                     None        False        False  17 Jun 2021
# 5                     None        False        False  31 Jan 2022
# 6                     None        False        False  22 Mar 2021
#
#    lastUpdatedOn     updated  version comments  \
# 0    20 Sep 2024  1726818902  1.44.08       []
# 1    13 Sep 2024  1726215541   8.50.0       []
# 2    19 Sep 2024  1726798791    3.3.4       []
# 3    18 Sep 2024  1726727356    4.8.1       []
# 4     7 Sep 2024  1725721859   1.55.0       []
# 5    30 Agu 2024  1725015501   2.19.0       []
# 6    19 Sep 2024  1726733257   3.2.81       []
#
#                              appId  \
# 0                 com.alloapp.yump
# 1          com.jago.digitalBanking
# 2  id.co.bankbkemobile.digitalbank
# 3                      com.btpn.dc
# 4               com.bcadigital.blu
# 5              id.co.bankraya.apps
# 6                  com.bnc.finance
#
#                                                  url
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...
# 5  https://play.google.com/store/apps/details?id=...
# 6  https://play.google.com/store/apps/details?id=...
#
# [7 rows x 45 columns]

# %%
def print_json(json_object):
  json_str = json.dumps(
    json_object, 
    indent=2, 
    sort_keys=True, 
    default=str
  )
  print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
print_json(app_infos[0])
# Out:
# {
#   "adSupported": false,
#   "appId": "com.alloapp.yump",
#   "categories": [
#     {
#       "id": "FINANCE",
#       "name": "Keuangan"
#     }
#   ],
#   "comments": [],
#   "containsAds": false,
#   "contentRating": "Rating 3+",
#   "contentRatingDescription": null,
#   "currency": "IDR",
#   "description": "Hi, kini Allo Bank untuk Android hadir!\r\n\r\nAplikasi yang melengkapimu! Sebuah Bank Digital dan dompet digital dengan fitur Pay Later dan Instant Cash.\r\n\r\nPendaftaran yang mudah. Hanya dengan 5 menit untuk mendaftar secara online!\r\n\r\nBebas biaya admin! Tidak ada biaya admin bulanan, minimum setoran awal, minimum saldo serta gratis biaya transfer ke Bank lain menggunakan fitur BI-FAST.\r\n\r\nBunga yang menarik, sesuaikan kebutuhanmu dengan produk tabungan atau deposito digital!\r\n\r\nBuka deposito dengan cepat dan mudah. Real time melalui satu genggaman!\r\n\r\nTarik tunai tanpa kartu di ATM Bank Mega! Tarik uang tunai dengan mudah dan cepat untuk semua kebutuhan transaksimu.\r\n\r\nDan dapatkan banyak keuntungan di setiap transaksimu!\r\n\r\nInfo lebih lanjut\r\nAllo Care 080 4110 4110\r\nWhatsApp 0822 0822 4110",
#   "descriptionHTML": "Hi, kini Allo Bank untuk Android hadir!<br><br>Aplikasi yang melengkapimu! Sebuah Bank Digital dan dompet digital dengan fitur Pay Later dan Instant Cash.<br><br>Pendaftaran yang mudah. Hanya dengan 5 menit untuk mendaftar secara online!<br><br>Bebas biaya admin! Tidak ada biaya admin bulanan, minimum setoran awal, minimum saldo serta gratis biaya transfer ke Bank lain menggunakan fitur BI-FAST.<br><br>Bunga yang menarik, sesuaikan kebutuhanmu dengan produk tabungan atau deposito digital!<br><br>Buka deposito dengan cepat dan mudah. Real time melalui satu genggaman!<br><br>Tarik tunai tanpa kartu di ATM Bank Mega! Tarik uang tunai dengan mudah dan cepat untuk semua kebutuhan transaksimu.<br><br>Dan dapatkan banyak keuntungan di setiap transaksimu!<br><br>Info lebih lanjut<br>Allo Care 080 4110 4110<br>WhatsApp 0822 0822 4110",
#   "developer": "PT. ALLO BANK INDONESIA Tbk",
#   "developerAddress": "ASEAN Tower Building 3rd Floor, Jl K.H Samanhudi No.10 Jakarta 10710, Indonesia",
#   "developerEmail": "allocare@allobank.com",
#   "developerId": "PT.+ALLO+BANK+INDONESIA+Tbk",
#   "developerWebsite": "https://allobank.com",
#   "free": true,
#   "genre": "Keuangan",
#   "genreId": "FINANCE",
#   "headerImage": "https://play-lh.googleusercontent.com/F-eWhDQuAoDNA-bcjqIMMEX_wkNzM6uz7Zn8BNfW3dHY-qojxn0ssVSLIr_W0FCwtzo",
#   "histogram": [
#     7546,
#     1020,
#     1380,
#     1540,
#     31175
#   ],
#   "icon": "https://play-lh.googleusercontent.com/0gw4GVJoKuQCDIz8DOXt5fQDEy-RD0BDnQge-BsbnBaBTmXWgqjydABvetmCqTXE1Gm2",
#   "inAppProductPrice": null,
#   "installs": "5.000.000+",
#   "lastUpdatedOn": "20 Sep 2024",
#   "minInstalls": 5000000,
#   "offersIAP": false,
#   "originalPrice": null,
#   "price": 0,
#   "privacyPolicy": "https://www.allobank.com/privacy",
#   "ratings": 42666,
#   "realInstalls": 8161673,
#   "released": "14 Mar 2022",
#   "reviews": 26596,
#   "sale": false,
#   "saleText": null,
#   "saleTime": null,
#   "score": 4.1198688,
#   "screenshots": [
#     "https://play-lh.googleusercontent.com/XC05yvBoIc_Q15qYcqVfLwGuDw2k-nPVj4roZOLK9nVSbQl69x_XePdt-Q9YBe0-AGcs",
#     "https://play-lh.googleusercontent.com/_BvUtqBYp6l2tSnfo9CYFzYXzIEVqHSSYSZxTfm8YZR8sm25t8RpdU_aXBfX7VVQKds",
#     "https://play-lh.googleusercontent.com/UVu5eYJxSA3zJHiH6A7vWpNXdT5852fcIFhlDgCXjeGxYDzz7-c3YRtUMGY2UUYUrGuE",
#     "https://play-lh.googleusercontent.com/wEgqZekLG3RLoxMaKSSPQWZi__-gjrenQ7ApJiWEz0DoEL4sgBXaCtB8MqS9pO89diQ",
#     "https://play-lh.googleusercontent.com/2ZqKBa7_FlCt7GA-5cOnAG4HY54ReXsZemCeXKFkshIoaia_R6gZTXAzp-gxp0_z204",
#     "https://play-lh.googleusercontent.com/Q40nApQHVxrLrKaV7qYRzMZN285WJ22Anbjljq2rDUwjuGHPWiGca-GJO66ZR_OJ0Es",
#     "https://play-lh.googleusercontent.com/FwE1BARkc0Eyfa2WtohYSXY2fJ-EP0dyPAU5YIIhUsdQU5F5HZLpmCwcV7B0yVYr4Bi3",
#     "https://play-lh.googleusercontent.com/qCBEsxSRs-s0nzuvk1__VZkxrupF5M-YxpfKUc0AJWw5qR0FpQeMlKm6KPt1xmGB2sI"
#   ],
#   "summary": "Allo Bank, perbankan digital baru yang akan membantu Anda memenuhi semua kebutuhan Anda.",
#   "title": "Allo Bank",
#   "updated": 1726818902,
#   "url": "https://play.google.com/store/apps/details?id=com.alloapp.yump&hl=id&gl=id",
#   "version": "1.44.08",
#   "video": "https://www.youtube.com/embed/g-IhngxaCn8?ps=play&vq=large&rel=0&autohide=1&showinfo=0",
#   "videoImage": "https://play-lh.googleusercontent.com/F-eWhDQuAoDNA-bcjqIMMEX_wkNzM6uz7Zn8BNfW3dHY-qojxn0ssVSLIr_W0FCwtzo"
# }

# %%
df.to_csv('BankDigital/dataset/info_BANK_MOBILE_GOOGLE_PLAY_Update21092024.csv', index=None, header=True)

# %%
app_reviews = []

for ap in tqdm(app_packages):
  for score in list(range(1, 6)):
    for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
      rvs, _ = reviews(
        ap,
        lang='id',
        country='id',
        sort=sort_order,
        count= 3000 if score == 3 else 1500,
        filter_score_with=score
      )
      for r in rvs:
        r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
        r['appId'] = ap
      app_reviews.extend(rvs)
# Out:
# 100%|██████████| 7/7 [05:47<00:00, 49.70s/it]

# %%
print_json(app_reviews[1])
# Out:
# {
#   "appId": "com.alloapp.yump",
#   "appVersion": "1.42.44",
#   "at": "2024-07-30 20:46:15",
#   "content": "Sebetulnya bagus untuk mempermudah dan kelancaran dalam transaksi. Tapi sayang suka eror. Kayak akun saya sampe seharian gak bisa di buka untuk transaksi. Padahal sudah lapor ke costomerservise juga belum akan perkembangan kelanjutannya sampe malam ini",
#   "repliedAt": "2024-07-31 11:52:45",
#   "replyContent": "Hai Sahabat Allo, mohon maaf untuk ketidaknyamanan yang kamu alami. Jika kamu masih mengalami kendala bisa tanyakan langsung ke Allo Care di 080 4110 4110, atau melalui Live Chat kami di bit.ly/AlloCare. Terima kasih, semoga harimu menyenangkan. -TA",
#   "reviewCreatedVersion": "1.42.44",
#   "reviewId": "9e6055d6-1efa-4bff-974c-0a4e8b015379",
#   "score": 1,
#   "sortOrder": "most_relevant",
#   "thumbsUpCount": 73,
#   "userImage": "https://play-lh.googleusercontent.com/a/ACg8ocJpF6rlQUu6BT5FWxQ_Fp_Q-FAxCWQO78wAS8juoVL_VWpWPA=mo",
#   "userName": "Suhardiyanto Ttv"
# }

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.to_csv('BankDigital/dataset/Newest_REVIEW_BANK_MOBILE_GOOGLE_PLAY_Update21092024.csv', index=None, header=True)
app_reviews_df.to_excel('BankDigital/dataset/Newest_REVIEW_BANK_MOBILE_GOOGLE_PLAY_Update21092024.xlsx', index=None, header=True)

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99920 entries, 0 to 99919
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              99920 non-null  object
#  1   userName              99920 non-null  object
#  2   userImage             99920 non-null  object
#  3   content               99920 non-null  object
#  4   score                 99920 non-null  int64
#  5   thumbsUpCount         99920 non-null  int64
#  6   reviewCreatedVersion  78367 non-null  object
#  7   at                    99920 non-null  datetime64[ns]
#  8   replyContent          77397 non-null  object
#  9   repliedAt             77397 non-null  datetime64[ns]
#  10  appVersion            78367 non-null  object
#  11  sortOrder             99920 non-null  object
#  12  appId                 99920 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 9.9+ MB

# %%
# Check for null values
print(app_reviews_df.isnull().sum())
# Out:
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion    21553
# at                          0
# replyContent            22523
# repliedAt               22523
# appVersion              21553
# sortOrder                   0
# appId                       0
# dtype: int64

# %%
data_df = app_reviews_df[['appId', 'content', 'score', 'at']]

# %%
data_df
# Out:
#                   appId                                            content  \
# 0      com.alloapp.yump  Sangat mengecewakan . Cs sangat lambat Untuk k...
# 1      com.alloapp.yump  Sebetulnya bagus untuk mempermudah dan kelanca...
# 2      com.alloapp.yump  Aplikasi ribet. Terlalu Banyak iming iming yg ...
# 3      com.alloapp.yump  Selalu menawarkan paylater, setelah di gunakan...
# 4      com.alloapp.yump  ulasan terbaru yah, saya coba mengganti alamat...
# ...                 ...                                                ...
# 99915   com.bnc.finance  Apa2 bisa pake Neo bank pokonya jangan ragu pa...
# 99916   com.bnc.finance  Sejauh ini sih fitur deposito neo wow sih yang...
# 99917   com.bnc.finance  Fitur neobank yang bikin happy banget adalah q...
# 99918   com.bnc.finance  Mantap banget untuk deposit dan nabung jangka ...
# 99919   com.bnc.finance  Aku sudah lama pakai NEO BANK .. dari deposto ...
#
#        score                  at
# 0          1 2024-07-22 02:44:38
# 1          1 2024-07-30 20:46:15
# 2          1 2024-09-09 18:47:56
# 3          1 2024-09-15 02:29:28
# 4          1 2024-09-06 20:06:21
# ...      ...                 ...
# 99915      5 2024-02-22 16:44:34
# 99916      5 2024-02-22 16:42:48
# 99917      5 2024-02-22 16:41:22
# 99918      5 2024-02-22 16:40:03
# 99919      5 2024-02-22 16:39:35
#
# [99920 rows x 4 columns]

# %%
print(data_df.isnull().sum())
# Out:
# appId      0
# content    0
# score      0
# at         0
# dtype: int64

# %%
data_df.to_csv('BankDigital/dataset/REVIEW_BANK_MOBILE_Playstore_21092024.csv', index=None, header=True)
data_df.to_excel('BankDigital/dataset/REVIEW_BANK_MOBILE_Playstore_21092024.xlsx', index=None, header=True)
